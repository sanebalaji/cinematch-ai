# %%
import pandas as pd

movies = pd.read_csv("../dataset/tmdb_5000_movies.csv")
credits = pd.read_csv("../dataset/tmdb_5000_credits.csv")

import sys
import os

sys.path.append(os.path.abspath(".."))
from nltk.stem.porter import PorterStemmer

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies.tail()
# Out:
#       budget                                             genres  \
# 4798  220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799    9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800       0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801       0                                                 []
# 4802       0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 4798                                                NaN    9367
# 4799                                                NaN   72766
# 4800  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801                        http://shanghaicalling.com/  126186
# 4802                                                NaN   25975
#
#                                                keywords original_language  \
# 4798  [{"id": 5616, "name": "united states\u2013mexi...                es
# ...

# %%
movies.shape
# Out:
# (4803, 20)

# %%
movies.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
movies['genres']
# Out:
# 0       [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1       [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2       [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3       [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4       [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#                               ...
# 4798    [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799    [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800    [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801                                                   []
# 4802                  [{"id": 99, "name": "Documentary"}]
# Name: genres, Length: 4803, dtype: object

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
movies.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
movies.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %%
movies.isnull()
# Out:
#       budget  genres  homepage     id  keywords  original_language  \
# 0      False   False     False  False     False              False
# 1      False   False     False  False     False              False
# 2      False   False     False  False     False              False
# 3      False   False     False  False     False              False
# 4      False   False     False  False     False              False
# ...      ...     ...       ...    ...       ...                ...
# 4798   False   False      True  False     False              False
# 4799   False   False      True  False     False              False
# 4800   False   False     False  False     False              False
# 4801   False   False     False  False     False              False
# 4802   False   False      True  False     False              False
#
#       original_title  overview  popularity  production_companies  \
# 0              False     False       False                 False
# ...

# %%
movies.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4798    False
# 4799    False
# 4800    False
# 4801    False
# 4802    False
# Length: 4803, dtype: bool

# %%
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
movies = movies.drop_duplicates()

# %%
movies = movies[
    [
        "id",
        "title",
        "overview",
        "genres",
        "keywords"
    ]
]

credits = credits[
    [
        "movie_id",
        "title",
        "cast",
        "crew"
    ]
]

# %%
movies.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
# ...

# %%
movies = movies.merge(
    credits,
    left_on="id",
    right_on="movie_id"
)

# %%
movies.head()
# Out:
#        id                                   title_x  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
# ...

# %%
movies.tail()
# Out:
#           id                    title_x  \
# 4798    9367                El Mariachi
# 4799   72766                  Newlyweds
# 4800  231617  Signed, Sealed, Delivered
# 4801  126186           Shanghai Calling
# 4802   25975          My Date with Drew
#
#                                                overview  \
# 4798  El Mariachi just wants to play his guitar and ...
# 4799  A newlywed couple's honeymoon is upended by th...
# 4800  "Signed, Sealed, Delivered" introduces a dedic...
# 4801  When ambitious New York attorney Sam is sent t...
# 4802  Ever since the second grade when he first saw ...
#
#                                                  genres  \
# 4798  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801                                                 []
# 4802                [{"id": 99, "name": "Documentary"}]
#
# ...

# %%
from model.preprocessing import convert

# %%
sample = "[{'id':28,'name':'Action'},{'id':12,'name':'Adventure'}]"

print(convert(sample))
# Out:
# ['Action', 'Adventure']

# %%
movies['genres']=  movies['genres'].apply(convert)

# %%
movies.head()
# Out:
#        id                                   title_x  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
movies = movies.drop(
    columns=[
        "movie_id",
        "title_y"
    ]
)

# %%
movies = movies.rename(
    columns={
        "title_x": "title"
    }
)

# %%
movies.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
movies["keywords"] = movies["keywords"].apply(convert)

# %%
movies.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
movies['cast'].iloc[0]
# Out:
# '[{"cast_id": 242, "character": "Jake Sully", "credit_id": "5602a8a7c3a3685532001c9a", "gender": 2, "id": 65731, "name": "Sam Worthington", "order": 0}, {"cast_id": 3, "character": "Neytiri", "credit_id": "52fe48009251416c750ac9cb", "gender": 1, "id": 8691, "name": "Zoe Saldana", "order": 1}, {"cast_id": 25, "character": "Dr. Grace Augustine", "credit_id": "52fe48009251416c750aca39", "gender": 1, "id": 10205, "name": "Sigourney Weaver", "order": 2}, {"cast_id": 4, "character": "Col. Quaritch", "credit_id": "52fe48009251416c750ac9cf", "gender": 2, "id": 32747, "name": "Stephen Lang", "order": 3}, {"cast_id": 5, "character": "Trudy Chacon", "credit_id": "52fe48009251416c750ac9d3", "gender": 1, "id": 17647, "name": "Michelle Rodriguez", "order": 4}, {"cast_id": 8, "character": "Selfridge", "credit_id": "52fe48009251416c750ac9e1", "gender": 2, "id": 1771, "name": "Giovanni Ribisi", "order": 5}, {"cast_id": 7, "character": "Norm Spellman", "credit_id": "52fe48009251416c750ac9dd", "gender"
# ...

# %%
from model.preprocessing import convert3

# %%
sample = """
[
 {"name":"Actor1"},
 {"name":"Actor2"},
 {"name":"Actor3"},
 {"name":"Actor4"},
 {"name":"Actor5"}
]
"""

print(convert3(sample))
# Out:
# ['Actor1', 'Actor2', 'Actor3']

# %%
import model.preprocessing as p

print(dir(p))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'convert', 'convert3', 'fetch_director', 'literal_eval']

# %%
import model.preprocessing as p

print(p.__file__)
# Out:
# c:\Users\saneb\OneDrive\Desktop\Movie-Recommendation-System\model\preprocessing.py

# %%
import importlib
import model.preprocessing

importlib.reload(model.preprocessing)

from model.preprocessing import convert3

# %%
movies["cast"] = movies["cast"].apply(convert3)

# %%
movies.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
import importlib
import model.preprocessing

importlib.reload(model.preprocessing)

from model.preprocessing import convert3

from model.preprocessing import fetch_director

# %%
# sample = [
#  {"job":"Producer","name":"Jon Landau"},
#  {"job":"Director","name":"James Cameron"},
#  {"job":"Writer","name":"James Cameron"}
# ]
# print(fetch_director(sample))

# %%
movies["crew"] = movies["crew"].apply(fetch_director)

# %%
movies.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
movies["overview"].isnull().sum()
# Out:
# np.int64(3)

# %%
movies[movies["overview"].isnull()]
# Out:
#           id                                       title overview  \
# 2656  370980  Chiamatemi Francesco - Il Papa della gente      NaN
# 4140  459488                 To Be Frank, Sinatra at 100      NaN
# 4431  292539                                 Food Chains      NaN
#
#              genres                                           keywords  \
# 2656        [Drama]                                  [pope, biography]
# 4140  [Documentary]  [music, actors, legendary perfomer, classic ho...
# 4431  [Documentary]                                                 []
#
#                                                    cast                 crew
# 2656  [Rodrigo de la Serna, Sergio Hernández, Àlex B...   [Daniele Luchetti]
# 4140                                  [Tony Oppedisano]  [Simon Napier-Bell]
# 4431                                                 []       [Sanjay Rawal]

# %%
movies.dropna(subset=["overview"], inplace=True)

# %%
movies["overview"] = movies["overview"].apply(lambda x: x.split())

# %%
movies.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
movies["tags"] = (
    movies["overview"]
    + movies["genres"]
    + movies["keywords"]
    + movies["cast"]
    + movies["crew"]
)

# %%
movies[["title","tags"]].head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                                 tags
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...

# %%
movies.loc[0, "tags"]
# Out:
# ['In',
#  'the',
#  '22nd',
#  'century,',
#  'a',
#  'paraplegic',
#  'Marine',
#  'is',
#  'dispatched',
#  'to',
#  'the',
#  'moon',
#  'Pandora',
#  'on',
#  'a',
#  'unique',
#  'mission,',
#  'but',
#  'becomes',
#  'torn',
#  'between',
#  'following',
#  'orders',
#  'and',
#  'protecting',
#  'an',
#  'alien',
#  'civilization.',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Science Fiction',
#  'culture clash',
#  'future',
#  'space war',
#  'space colony',
#  'society',
#  'space travel',
#  'futuristic',
#  'romance',
#  'space',
#  'alien',
#  'tribe',
#  'alien planet',
#  'cgi',
#  'marine',
#  'soldier',
#  'battle',
#  'love affair',
#  'anti war',
#  'power relations',
#  'mind and soul',
#  '3d',
#  'Sam Worthington',
#  'Zoe Saldana',
#  'Sigourney Weaver',
#  'James Cameron']

# %%
movies["genres"] = movies["genres"].apply(
    lambda x: [i.replace(" ", "") for i in x]
)

# %%
movies["keywords"] = movies["keywords"].apply(
    lambda x: [i.replace(" ", "") for i in x]
)

# %%
movies["cast"] = movies["cast"].apply(
    lambda x: [i.replace(" ", "") for i in x]
)

# %%
movies["crew"] = movies["crew"].apply(
    lambda x: [i.replace(" ", "") for i in x]
)

# %%
movies[["title", "genres", "cast", "crew"]].head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
#                                             cast                crew
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver]      [JamesCameron]
# 1     [JohnnyDepp, OrlandoBloom, KeiraKnightley]     [GoreVerbinski]
# 2      [DanielCraig, ChristophWaltz, LéaSeydoux]         [SamMendes]
# 3      [ChristianBale, MichaelCaine, GaryOldman]  [ChristopherNolan]
# ...

# %%
movies.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
# ...

# %%
# movies["tags"] = (
#     movies["overview"]
#     + movies["genres"]
#     + movies["keywords"]
#     + movies["cast"]
#     + movies["crew"]
# )

# %%
movies.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
# ...

# %%
ps = PorterStemmer()

# %%
print(ps.stem("played"))
# Out:
# play

# %%
print(ps.stem("loving"))
# Out:
# love

# %%
print(ps.stem("running"))
# Out:
# run

# %%
print(ps.stem("playing"))
print(ps.stem("played"))
print(ps.stem("running"))
print(ps.stem("loving"))
print(ps.stem("connections"))
# Out:
# play
# play
# run
# love
# connect

# %%
from model.nlp_utils import stem

# %%
print(stem("playing loved fighting aliens"))
# Out:
# play love fight alien

# %%
movies.columns.tolist()
# Out:
# ['id', 'title', 'overview', 'genres', 'keywords', 'cast', 'crew', 'tags']

# %%
movies["tags"] = movies["tags"].apply(lambda x: " ".join(x))

# %%
movies["tags"] = movies["tags"].apply(stem)

# %%
movies[["title","tags"]].head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                                 tags
# 0  in the 22nd century, a parapleg marin is dispa...
# 1  captain barbossa, long believ to be dead, ha c...
# 2  a cryptic messag from bond’ past send him on a...
# 3  follow the death of district attorney harvey d...
# 4  john carter is a war-weary, former militari ca...

# %%
movies
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4798    9367                               El Mariachi
# 4799   72766                                 Newlyweds
# 4800  231617                 Signed, Sealed, Delivered
# 4801  126186                          Shanghai Calling
# 4802   25975                         My Date with Drew
#
#                                                overview  \
# 0     [In, the, 22nd, century,, a, paraplegic, Marin...
# 1     [Captain, Barbossa,, long, believed, to, be, d...
# 2     [A, cryptic, message, from, Bond’s, past, send...
# 3     [Following, the, death, of, District, Attorney...
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer(
    max_features=5000,
    stop_words="english"
)

# %%
cv.fit(movies['tags'])
# Out:
# CountVectorizer(max_features=5000, stop_words='english')

# %%
cv.transform(movies["tags"])
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 179147 stored elements and shape (4800, 5000)>

# %%
vectors = cv.fit_transform(
    movies["tags"]
)

# %%
vectors.shape
# Out:
# (4800, 5000)

# %%
vectors = vectors.toarray()

# %%
vectors[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(5000,))

# %%
features = cv.get_feature_names_out()

# %%
features[:20]
# Out:
# array(['000', '007', '10', '100', '11', '12', '13', '14', '15', '16',
#        '16th', '17', '17th', '18', '18th', '19', '1910', '1920', '1930',
#        '1940'], dtype=object)

# %%
len(features)
# Out:
# 5000

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vectors)

# %%
similarity.shape
# Out:
# (4800, 4800)

# %%
similarity[0]
# Out:
# array([1.        , 0.06622662, 0.06554735, ..., 0.04406051, 0.03244428,
#        0.        ], shape=(4800,))

# %%
movie_index= movies[movies['title']=='Avatar'].index[0]

distance = list(enumerate(similarity[movie_index]))

distance = sorted(distance, key = lambda x:x[1], reverse= True)

for i in distance[1:6]:
    print(movies.iloc[i[0]].title)


# O(n log n)
# Out:
# Aliens
# Silent Running
# Alien
# Moonraker
# Mission to Mars

# %%
def recommend(movie):
    movie_index= movies[movies['title']==movie].index[0]

    distance = list(enumerate(similarity[movie_index]))

    distance = sorted(distance, key = lambda x:x[1], reverse= True)

    for i in distance[1:6]:
        print(movies.iloc[i[0]].title)

# %%
recommend("Avatar")
# Out:
# Aliens
# Silent Running
# Alien
# Moonraker
# Mission to Mars

# %%
recommend("Batman Begins")
# Out:
# The Dark Knight
# The Dark Knight Rises
# Batman
# Batman & Robin
# Batman Returns

# %%
recommend("Iron Man")
# Out:
# Iron Man 3
# Iron Man 2
# Avengers: Age of Ultron
# Captain America: Civil War
# The Avengers

# %%
# recommend("Avata")

# %%
movies["title"].values
# Out:
# array(['Avatar', "Pirates of the Caribbean: At World's End", 'Spectre',
#        ..., 'Signed, Sealed, Delivered', 'Shanghai Calling',
#        'My Date with Drew'], shape=(4800,), dtype=object)

# %%
def recommend(movie):
    
    if movie not in movies['title'].values:
        print("Movie not found!")
        return


    movie_index= movies[movies['title']==movie].index[0]

    distance = list(enumerate(similarity[movie_index]))

    distance = sorted(distance, key = lambda x:x[1], reverse= True)

    for i in distance[1:6]:
        print(movies.iloc[i[0]].title)

# %%
recommend("ABCDEFG")
# Out:
# Movie not found!

# %%
def recommend(movie):

    matched_movies = movies[
        movies["title"].str.contains(
            movie,
            case=False,
            na=False
        )
    ]

    if matched_movies.empty:
        print("Movie not found!")
        return

    movie_index = matched_movies.index[0]

    distance = list(enumerate(similarity[movie_index]))

    distance = sorted(
        distance,
        key=lambda x: x[1],
        reverse=True
    )

    print(f"\nRecommendations for: {movies.iloc[movie_index].title}\n")

    for i in distance[1:6]:
        print(movies.iloc[i[0]].title)

# %%
recommend("AVA")
# Out:
# Recommendations for: Avatar
#
# Aliens
# Silent Running
# Alien
# Moonraker
# Mission to Mars

# %%
recommend("bat")
# Out:
# Recommendations for: Batman v Superman: Dawn of Justice
#
# Man of Steel
# Suicide Squad
# Batman Begins
# Superman
# Superman III

# %%
recommend("xyzxyz")
# Out:
# Movie not found!

# %%
import pickle

# %%
pickle.dump(
    movies,
    open("../artifacts/movies.pkl","wb")
)

# %%
pickle.dump(
    similarity,
    open("../artifacts/similarity.pkl","wb")
)

# %%
from model.recommender import recommend

# %%
recommend("Avatar")
# Out:
# Recommendations for: Avatar
#
# Aliens
# Silent Running
# Alien
# Moonraker
# Mission to Mars

# %%
from model.tmdb import search_movie

# %%
data = search_movie("Avatar")

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['page', 'results', 'total_pages', 'total_results'])

# %%
data["results"][0]
# Out:
# {'adult': False,
#  'backdrop_path': '/vL5LR6WdxWPjLPFRLe133jXWsh5.jpg',
#  'genre_ids': [878, 28, 12],
#  'id': 19995,
#  'title': 'Avatar',
#  'original_language': 'en',
#  'original_title': 'Avatar',
#  'overview': 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.',
#  'popularity': 36.7009,
#  'poster_path': '/gKY6q7SjCkAU6FqvqWybDYgUKIF.jpg',
#  'release_date': '2009-12-16',
#  'softcore': False,
#  'video': False,
#  'vote_average': 7.608,
#  'vote_count': 34198}

# %%
import model.tmdb as tmdb

print(dir(tmdb))
# Out:
# ['API_KEY', 'BASE_URL', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'load_dotenv', 'os', 'requests', 'search_movie']

# %%
import model.tmdb as tmdb

print(tmdb.__file__)
# Out:
# c:\Users\saneb\OneDrive\Desktop\Movie-Recommendation-System\model\tmdb.py

# %%
import importlib
import model.tmdb as tmdb

importlib.reload(tmdb)

print(dir(tmdb))
# Out:
# ['API_KEY', 'BASE_URL', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'get_movie_details', 'load_dotenv', 'os', 'requests', 'search_movie']

# %%
from model.tmdb import get_movie_details

print(get_movie_details)
# Out:
# <function get_movie_details at 0x000002766686B530>

# %%
movie = get_movie_details(19995)

# %%
movie.keys()
# Out:
# dict_keys(['adult', 'backdrop_path', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id', 'imdb_id', 'origin_country', 'original_language', 'original_title', 'overview', 'popularity', 'poster_path', 'production_companies', 'production_countries', 'release_date', 'revenue', 'runtime', 'softcore', 'spoken_languages', 'status', 'tagline', 'title', 'video', 'vote_average', 'vote_count'])

# %%
movie["title"]
# Out:
# 'Avatar'

# %%
movie["runtime"]
# Out:
# 162

# %%
movie["poster_path"]
# Out:
# '/gKY6q7SjCkAU6FqvqWybDYgUKIF.jpg'

# %%
poster = "https://image.tmdb.org/t/p/w500" + movie["poster_path"]

poster
# Out:
# 'https://image.tmdb.org/t/p/w500/gKY6q7SjCkAU6FqvqWybDYgUKIF.jpg'

# %%
import importlib
import model.tmdb as tmdb

importlib.reload(tmdb)

print(dir(tmdb))
# Out:
# ['API_KEY', 'BASE_URL', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'get_movie_details', 'get_poster_url', 'load_dotenv', 'os', 'requests', 'search_movie']

# %%
from model.tmdb import get_poster_url

# %%
tmdb.get_poster_url(movie["poster_path"])
# Out:
# 'https://image.tmdb.org/t/p/w500/gKY6q7SjCkAU6FqvqWybDYgUKIF.jpg'

# %%
get_poster_url(movie["poster_path"])
# Out:
# 'https://image.tmdb.org/t/p/w500/gKY6q7SjCkAU6FqvqWybDYgUKIF.jpg'

# %%
import importlib
import model.tmdb as tmdb

importlib.reload(tmdb)

print(dir(tmdb))
# Out:
# ['API_KEY', 'BASE_URL', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'fetch_complete_movie', 'get_movie_details', 'get_poster_url', 'load_dotenv', 'os', 'requests', 'search_movie']

# %%
from model.tmdb import fetch_complete_movie

# %%
movie = fetch_complete_movie("Avatar")

# %%
movie
# Out:
# {'id': 19995,
#  'title': 'Avatar',
#  'poster': 'https://image.tmdb.org/t/p/w500/gKY6q7SjCkAU6FqvqWybDYgUKIF.jpg',
#  'rating': 7.609,
#  'overview': 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.',
#  'release_date': '2009-12-16',
#  'runtime': 162,
#  'genres': ['Science Fiction', 'Action', 'Adventure']}

# %%
from model.recommender import recommend

# %%
movies = recommend("Batman")
# Out:
# Recommendations for: Batman v Superman: Dawn of Justice
#
# Man of Steel
# Suicide Squad
# Batman Begins
# Superman
# Superman III

# %%
type(movies)
# Out:
# NoneType

# %%
import inspect
from model.recommender import recommend

print(inspect.getsource(recommend))
# Out:
# similarity = pickle.load(
#     open(BASE_DIR / "artifacts" / "similarity.pkl", "rb")
# )

# %%
import model.recommender

print(model.recommender.__file__)
# Out:
# c:\Users\saneb\OneDrive\Desktop\Movie-Recommendation-System\model\recommender.py

# %%
import importlib
import model.recommender

importlib.reload(model.recommender)

from model.recommender import recommend

# %%
movies = recommend("Batman")
print(type(movies))
print(movies)
# Out:
# Recommendations for: Batman v Superman: Dawn of Justice
#
# <class 'list'>
# ...

# %%
movies[0]
# Out:
# {'id': 49521,
#  'title': 'Man of Steel',
#  'poster': 'https://image.tmdb.org/t/p/w500/8GFtkImmK0K1VaUChR0n9O61CFU.jpg',
#  'rating': 6.652,
#  'overview': 'A young boy learns that he has extraordinary powers and is not of this earth. As a young man, he journeys to discover where he came from and what he was sent here to do. But the hero in him must emerge if he is to save the world from annihilation and become the symbol of hope for all mankind.',
#  'release_date': '2013-06-12',
#  'runtime': 143,
#  'genres': ['Action', 'Adventure', 'Science Fiction']}

# %%
movie = fetch_complete_movie("Avatar")

# %%
movie.keys()
# Out:
# dict_keys(['id', 'title', 'poster', 'rating', 'overview', 'release_date', 'runtime', 'genres'])

# %%
# %load_ext autoreload
# %autoreload 2

# %%
movie = fetch_complete_movie("Avatar")

print(movie)
# Out:
# {'id': 19995, 'title': 'Avatar', 'poster': 'https://image.tmdb.org/t/p/w500/gKY6q7SjCkAU6FqvqWybDYgUKIF.jpg', 'rating': 7.609, 'overview': 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.', 'release_date': '2009-12-16', 'runtime': 162, 'genres': ['Science Fiction', 'Action', 'Adventure']}

# %%
import os
import sys

sys.path.append(os.path.abspath(".."))

# %%
from model.tmdb import fetch_complete_movie

# %%
movie = fetch_complete_movie("Avatar")
movie.keys()
# Out:
# dict_keys(['id', 'title', 'poster', 'rating', 'overview', 'release_date', 'runtime', 'genres'])

# %%
import os
import sys

sys.path.append("../")

from model.tmdb import fetch_complete_movie

# %%
import inspect
from model.tmdb import fetch_complete_movie

print(inspect.getfile(fetch_complete_movie))
# Out:
# c:\Users\saneb\OneDrive\Desktop\Movie-Recommendation-System\model\tmdb.py

# %%
import inspect

print(inspect.getsource(fetch_complete_movie))
# Out:
#     response = requests.get(url, params=params)

# %%
import inspect
from model.tmdb import fetch_complete_movie

print(inspect.getfile(fetch_complete_movie))
# Out:
# c:\Users\saneb\OneDrive\Desktop\Movie-Recommendation-System\model\tmdb.py

# %%
import inspect

print(inspect.getsource(fetch_complete_movie))
# Out:
#     response = requests.get(url, params=params)

# %%
import inspect
from model import tmdb

print(tmdb.fetch_complete_movie)
print(inspect.getsource(tmdb.fetch_complete_movie))
# Out:
# <function fetch_complete_movie at 0x00000276669AC510>
#     response = requests.get(url, params=params)

# %%
from model import tmdb

movie = tmdb.fetch_complete_movie("Avatar")

print(movie)
# Out:
# {'id': 19995, 'title': 'Avatar', 'poster': 'https://image.tmdb.org/t/p/w500/gKY6q7SjCkAU6FqvqWybDYgUKIF.jpg', 'rating': 7.609, 'overview': 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.', 'release_date': '2009-12-16', 'runtime': 162, 'genres': ['Science Fiction', 'Action', 'Adventure']}

# %%
from model.tmdb import fetch_complete_movie

movie = fetch_complete_movie("Avatar")

# %%
import model.tmdb as tmdb

print(tmdb.__file__)
# Out:
# c:\Users\saneb\OneDrive\Desktop\Movie-Recommendation-System\model\tmdb.py

# %%
print(tmdb.fetch_complete_movie.__code__.co_firstlineno)
# Out:
# 45

# %%
import os
import sys

sys.path.append("..")

from model.tmdb import fetch_complete_movie

movie = fetch_complete_movie("Avatar")

print(movie)
# Out:
# {'id': 19995, 'title': 'Avatar', 'poster': 'https://image.tmdb.org/t/p/w500/gKY6q7SjCkAU6FqvqWybDYgUKIF.jpg', 'rating': 7.609, 'overview': 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.', 'release_date': '2009-12-16', 'runtime': 162, 'genres': ['Science Fiction', 'Action', 'Adventure']}

# %%
import model.tmdb as tmdb

print(tmdb.__file__)
# Out:
# c:\Users\saneb\OneDrive\Desktop\Movie-Recommendation-System\model\tmdb.py

# %%
import inspect
import model.tmdb as tmdb

print(inspect.getsource(tmdb))
# Out:
# import os
# import requests
#
# from dotenv import load_dotenv
#
# load_dotenv()
#
# API_KEY = os.getenv("TMDB_API_KEY")
#
# BASE_URL = "https://api.themoviedb.org/3"
#
# def search_movie(movie_name):
#
#     url = f"{BASE_URL}/search/movie"
#
#     params = {
#         "api_key": API_KEY,
#         "query": movie_name
#     }
#
#     response = requests.get(url, params=params)
#
#     return response.json()
#
# def get_movie_details(movie_id):
#
#     url = f"{BASE_URL}/movie/{movie_id}"
#
#     params = {
#         "api_key": API_KEY
#     }
#
#     response = requests.get(url, params=params)
#
#     return response.json()
#
# def get_movie_cast(movie_id):
#
#     url = f"{BASE_URL}/movie/{movie_id}/credits"
#
#     params = {
#         "api_key": API_KEY
#     }
#
#     response = requests.get(url, params=params)
#
#     data = response.json()
#
#     cast = []
#
#     for actor in data["cast"][:5]:
#
#         profile = None
#
#         if actor["profile_path"]:
#
# ...

# %%
from model import tmdb

movie = tmdb.fetch_complete_movie("Avatar")

print(movie.keys())
print(movie["cast"])
# Out:
# dict_keys(['id', 'title', 'poster', 'rating', 'overview', 'release_year', 'language', 'runtime', 'genres', 'cast'])
# [{'name': 'Sam Worthington', 'character': 'Jake Sully', 'photo': 'https://image.tmdb.org/t/p/w500/vM1WIfYQ1HUBtlVPwB9Hp9fLcn8.jpg'}, {'name': 'Zoe Saldaña', 'character': 'Neytiri', 'photo': 'https://image.tmdb.org/t/p/w500/fCJuIn1PMUQtYdRRSnnoZeMJVWs.jpg'}, {'name': 'Sigourney Weaver', 'character': 'Dr. Grace Augustine', 'photo': 'https://image.tmdb.org/t/p/w500/wTSnfktNBLd6kwQxgvkqYw6vEon.jpg'}, {'name': 'Stephen Lang', 'character': 'Colonel Miles Quaritch', 'photo': 'https://image.tmdb.org/t/p/w500/gnO5VfkDgA2fsHweD0622LUY3Hu.jpg'}, {'name': 'Michelle Rodriguez', 'character': 'Trudy Chacon', 'photo': 'https://image.tmdb.org/t/p/w500/wVcbrae4eRqGMFZz8Eh52Dl1biP.jpg'}]
